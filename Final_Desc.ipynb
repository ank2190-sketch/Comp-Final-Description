# %% [markdown]
# ### Assignment 9: Comp Final Description

# %% [markdown]
# The goal is to compare the difference of two large Global Climate Models (GCMs); CMIP6 and CMIP5 and compare it the Regional Climate Model (RCM) CORDEX-Africa.

# %% [markdown]
# Data is sourced from the **IPCC WGI Interactive Atlas** as NetCDF files.

# %% [markdown]
# Potential graphs of generation
# + Fig 1 - Cartopy Map; mean
# + Fig 2 - Cartpoy Map; CMIP6 minus CMIP5 (differnce)
# + Fig 3 - Cartopy Map; CORDEX minus CMIP6
# + Fig 4 - Time Series; Regional Avergae over time
# + Fig 5 - Histogram; Distribution of Values Across Models
# + Fig 6 - Zonal Mean Plot; Latitude vs Longitude
